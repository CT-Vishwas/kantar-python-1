# %% [markdown]
# # This is a python demo

# %%
print("Helloworld")
# Out:
# Helloworld

# %%
# extract user name from email id
email_id = "vishwas@cloudthat.com"
username = email_id[:email_id.index('@')]
print(username)
# Out:
# vishwas

# %%
def extract_username(email):
    return email[:email.index('@')]

# %%
print(extract_username("vishwas123@cloiudthat.com"))
# Out:
# vishwas123
