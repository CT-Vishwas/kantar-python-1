# %% [markdown]
# # Events Data Analysis

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
BASE_DIR = "C:\\Users\\VishwasKSingh\\Workspace\\kantar-workspace-1\\my_project\\data\\"

# %%
registrations_df = pd.read_csv(BASE_DIR+"registrations.csv")

# %%
pricing_df = pd.read_csv(BASE_DIR+"pricing.csv")
events_df = pd.read_csv(BASE_DIR+"events.csv")
channels_df = pd.read_csv(BASE_DIR+"channels.csv")

# %%
attendees_df = pd.read_json(BASE_DIR+"attendees.json")

# %%
registrations_df.head()
# Out:
#      reg_id event_id     attendee_email     reg_timestamp payment_status  \
# 0  RE001000     E001  user0@example.com  2025-12-31 10:00           paid
# 1  RE001001     E001  user1@example.com  2025-12-18 10:00      cancelled
# 2  RE001002     E001  user2@example.com  2025-12-23 10:00        pending
# 3  RE001003     E001  user3@example.com  2026-01-11 10:00           paid
# 4  RE001004     E001  user4@example.com  2025-12-14 10:00        pending
#
#   ticket_type
# 0   earlybird
# 1    standard
# 2     student
# 3     student
# 4    standard

# %%
channels_df.head()
# Out:
#   event_id  channel  spend  impressions
# 0     E001    email   7000        35000
# 1     E001   social   5000        10000
# 2     E001  partner   7000        20000
# 3     E002    email   5000        35000
# 4     E002   social   5000        10000

# %%
pricing_df.head()
# Out:
#   event_id  base_price discount_code  discount_pct currency
# 0     E001        3000     STUDENT15            15      INR
# 1     E002        3000       EARLY10            10      INR
# 2     E003        3000          NY25            25      INR
# 3     E004        3000          NY25            25      INR
# 4     E005        2000           NaN             0      INR

# %%
events_df.head()
# Out:
#   event_id                        topic       city  venue_capacity  \
# 0     E001                   Python OOP  Bengaluru              50
# 1     E002               Data Wrangling  Bengaluru              30
# 2     E003                   Python OOP  Bengaluru              40
# 3     E004                   Python OOP     Mysuru              60
# 4     E005  Machine Learning Essentials  Bengaluru              40
#
#   scheduled_date_time instructor_id
# 0    2026-01-13 10:00          I001
# 1    2026-01-16 14:00          I001
# 2    2026-01-19 10:00          I003
# 3    2026-01-22 10:00          I002
# 4    2026-01-25 14:00          I002

# %%
attendees_df.head()
# Out:
#       attendee_email    company          role       city   industry  \
# 0  user0@example.com    Contoso       Student       Pune         IT
# 1  user1@example.com  Northwind      Engineer     Mysuru  Education
# 2  user2@example.com   Fabrikam       Student       Pune    Finance
# 3  user3@example.com   Fabrikam  Data Analyst       Pune    Finance
# 4  user4@example.com    Contoso      Engineer  Hyderabad    Finance
#
#                                                notes
# 0  Reached via partner. Promo=STUDENT15; Phone:+9...
# 1  Reached via email. Promo=STUDENT15; Phone:+91-...
# 2  Reached via partner. Promo=STUDENT15; Phone:+9...
# 3  Reached via email. Promo=NA; Phone:+91-7059780...
# 4  Reached via partner. Promo=NA; Phone:+91-97425...

# %%
attendees_df["notes"][0]
# Out:
# 'Reached via partner. Promo=STUDENT15; Phone:+91-7564409423; UTM=utm_source=email&utm_campaign=Q1_ML'

# %%
registrations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reg_id          421 non-null    object
#  1   event_id        421 non-null    object
#  2   attendee_email  421 non-null    object
#  3   reg_timestamp   421 non-null    object
#  4   payment_status  421 non-null    object
#  5   ticket_type     421 non-null    object
# dtypes: object(6)
# memory usage: 19.9+ KB

# %%
pricing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   event_id       12 non-null     object
#  1   base_price     12 non-null     int64
#  2   discount_code  11 non-null     object
#  3   discount_pct   12 non-null     int64
#  4   currency       12 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 612.0+ bytes

# %%
events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             12 non-null     object
#  1   topic                12 non-null     object
#  2   city                 12 non-null     object
#  3   venue_capacity       12 non-null     int64
#  4   scheduled_date_time  12 non-null     object
#  5   instructor_id        12 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 708.0+ bytes

# %%
channels_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   event_id     36 non-null     object
#  1   channel      36 non-null     object
#  2   spend        36 non-null     int64
#  3   impressions  36 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.3+ KB

# %%
pricing_df.isna().sum()
# Out:
# event_id         0
# base_price       0
# discount_code    1
# discount_pct     0
# currency         0
# dtype: int64

# %%
pricing_df.fillna('NA', inplace = True)

# %%
pricing_df.isna().sum()
# Out:
# event_id         0
# base_price       0
# discount_code    0
# discount_pct     0
# currency         0
# dtype: int64

# %%
attendees_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   attendee_email  58 non-null     object
#  1   company         58 non-null     object
#  2   role            58 non-null     object
#  3   city            58 non-null     object
#  4   industry        58 non-null     object
#  5   notes           58 non-null     object
# dtypes: object(6)
# memory usage: 2.8+ KB

# %% [markdown]
# Merging Events & Pricing

# %%
event_pricing = pd.merge(events_df, pricing_df, on='event_id', how="inner")

# %%
event_pricing.head()
# Out:
#   event_id                        topic       city  venue_capacity  \
# 0     E001                   Python OOP  Bengaluru              50
# 1     E002               Data Wrangling  Bengaluru              30
# 2     E003                   Python OOP  Bengaluru              40
# 3     E004                   Python OOP     Mysuru              60
# 4     E005  Machine Learning Essentials  Bengaluru              40
#
#   scheduled_date_time instructor_id  base_price discount_code  discount_pct  \
# 0    2026-01-13 10:00          I001        3000     STUDENT15            15
# 1    2026-01-16 14:00          I001        3000       EARLY10            10
# 2    2026-01-19 10:00          I003        3000          NY25            25
# 3    2026-01-22 10:00          I002        3000          NY25            25
# 4    2026-01-25 14:00          I002        2000            NA             0
#
#   currency
# 0      INR
# 1      INR
# 2      INR
# 3      INR
# 4      INR

# %%
registrations_attendees = pd.merge(registrations_df,attendees_df, on="attendee_email", how="inner")

# %%
registrations_attendees.head()
# Out:
#      reg_id event_id     attendee_email     reg_timestamp payment_status  \
# 0  RE001000     E001  user0@example.com  2025-12-31 10:00           paid
# 1  RE001001     E001  user1@example.com  2025-12-18 10:00      cancelled
# 2  RE001002     E001  user2@example.com  2025-12-23 10:00        pending
# 3  RE001003     E001  user3@example.com  2026-01-11 10:00           paid
# 4  RE001004     E001  user4@example.com  2025-12-14 10:00        pending
#
#   ticket_type    company          role       city   industry  \
# 0   earlybird    Contoso       Student       Pune         IT
# 1    standard  Northwind      Engineer     Mysuru  Education
# 2     student   Fabrikam       Student       Pune    Finance
# 3     student   Fabrikam  Data Analyst       Pune    Finance
# 4    standard    Contoso      Engineer  Hyderabad    Finance
#
#                                                notes
# 0  Reached via partner. Promo=STUDENT15; Phone:+9...
# 1  Reached via email. Promo=STUDENT15; Phone:+91-...
# 2  Reached via partner. Promo=STUDENT15; Phone:+9...
# 3  Reached via email. Promo=NA; Phone:+91-7059780...
# 4  Reached via partner. Promo=NA; Phone:+91-97425...

# %% [markdown]
# Calculating the Effective price

# %%
event_pricing["effective_price"] = event_pricing["base_price"] * (1 - (event_pricing["discount_pct"]/100))

# %%
event_pricing.head()
# Out:
#   event_id                        topic       city  venue_capacity  \
# 0     E001                   Python OOP  Bengaluru              50
# 1     E002               Data Wrangling  Bengaluru              30
# 2     E003                   Python OOP  Bengaluru              40
# 3     E004                   Python OOP     Mysuru              60
# 4     E005  Machine Learning Essentials  Bengaluru              40
#
#   scheduled_date_time instructor_id  base_price discount_code  discount_pct  \
# 0    2026-01-13 10:00          I001        3000     STUDENT15            15
# 1    2026-01-16 14:00          I001        3000       EARLY10            10
# 2    2026-01-19 10:00          I003        3000          NY25            25
# 3    2026-01-22 10:00          I002        3000          NY25            25
# 4    2026-01-25 14:00          I002        2000            NA             0
#
#   currency  effective_price
# 0      INR           2550.0
# 1      INR           2700.0
# 2      INR           2250.0
# 3      INR           2250.0
# 4      INR           2000.0

# %% [markdown]
# Converting datetime types

# %%
event_pricing["scheduled_date_time"] = pd.to_datetime(event_pricing["scheduled_date_time"])

# %%
event_pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             12 non-null     object
#  1   topic                12 non-null     object
#  2   city                 12 non-null     object
#  3   venue_capacity       12 non-null     int64
#  4   scheduled_date_time  12 non-null     datetime64[ns]
#  5   instructor_id        12 non-null     object
#  6   base_price           12 non-null     int64
#  7   discount_code        12 non-null     object
#  8   discount_pct         12 non-null     int64
#  9   currency             12 non-null     object
#  10  effective_price      12 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 1.2+ KB

# %%
registrations_attendees["reg_timestamp"] = pd.to_datetime(registrations_attendees["reg_timestamp"])

# %%
registrations_attendees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reg_id          421 non-null    object
#  1   event_id        421 non-null    object
#  2   attendee_email  421 non-null    object
#  3   reg_timestamp   421 non-null    datetime64[ns]
#  4   payment_status  421 non-null    object
#  5   ticket_type     421 non-null    object
#  6   company         421 non-null    object
#  7   role            421 non-null    object
#  8   city            421 non-null    object
#  9   industry        421 non-null    object
#  10  notes           421 non-null    object
# dtypes: datetime64[ns](1), object(10)
# memory usage: 36.3+ KB

# %% [markdown]
# How many unique values are there in few categorical columns

# %%
registrations_attendees['role'].nunique()
# Out:
# 4

# %%
registrations_attendees['industry'].nunique()
# Out:
# 4

# %% [markdown]
# We will represent the categorical values as a category dtype for memory efficiency

# %%
columns_to_convert = ['payment_status', 'ticket_type','city','role','industry']
for col in columns_to_convert:
    registrations_attendees[col] = registrations_attendees[col].astype('category')

# %%
registrations_attendees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   reg_id          421 non-null    object
#  1   event_id        421 non-null    object
#  2   attendee_email  421 non-null    object
#  3   reg_timestamp   421 non-null    datetime64[ns]
#  4   payment_status  421 non-null    category
#  5   ticket_type     421 non-null    category
#  6   company         421 non-null    object
#  7   role            421 non-null    category
#  8   city            421 non-null    category
#  9   industry        421 non-null    category
#  10  notes           421 non-null    object
# dtypes: category(5), datetime64[ns](1), object(5)
# memory usage: 22.8+ KB

# %% [markdown]
# Do the same in event_pricing

# %%
event_pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             12 non-null     object
#  1   topic                12 non-null     object
#  2   city                 12 non-null     object
#  3   venue_capacity       12 non-null     int64
#  4   scheduled_date_time  12 non-null     datetime64[ns]
#  5   instructor_id        12 non-null     object
#  6   base_price           12 non-null     int64
#  7   discount_code        12 non-null     object
#  8   discount_pct         12 non-null     int64
#  9   currency             12 non-null     object
#  10  effective_price      12 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(3), object(6)
# memory usage: 1.2+ KB

# %%
event_pricing['topic'].nunique()
# Out:
# 3

# %%
columns_to_convert = ['city','topic']
for col in columns_to_convert:
    event_pricing[col] = event_pricing[col].astype('category')

# %%
event_pricing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             12 non-null     object
#  1   topic                12 non-null     category
#  2   city                 12 non-null     category
#  3   venue_capacity       12 non-null     int64
#  4   scheduled_date_time  12 non-null     datetime64[ns]
#  5   instructor_id        12 non-null     object
#  6   base_price           12 non-null     int64
#  7   discount_code        12 non-null     object
#  8   discount_pct         12 non-null     int64
#  9   currency             12 non-null     object
#  10  effective_price      12 non-null     float64
# dtypes: category(2), datetime64[ns](1), float64(1), int64(3), object(4)
# memory usage: 1.3+ KB

# %%
combined_all = pd.merge(event_pricing,registrations_attendees, on="event_id", how="inner")

# %%
combined_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 421 entries, 0 to 420
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   event_id             421 non-null    object
#  1   topic                421 non-null    category
#  2   city_x               421 non-null    category
#  3   venue_capacity       421 non-null    int64
#  4   scheduled_date_time  421 non-null    datetime64[ns]
#  5   instructor_id        421 non-null    object
#  6   base_price           421 non-null    int64
#  7   discount_code        421 non-null    object
#  8   discount_pct         421 non-null    int64
#  9   currency             421 non-null    object
#  10  effective_price      421 non-null    float64
#  11  reg_id               421 non-null    object
#  12  attendee_email       421 non-null    object
#  13  reg_timestamp        421 non-null    datetime64[ns]
#  14  payment_status       421 non-null    category
#  15  ticket_type          421 non-null    category
#  16  company              421 non-null    object
#  17  role                 421 non-null    category
#  18  city_y               421 non-null    category
#  19  industry             421 non-null    category
#  20  notes                421 non-null    object
# dtypes: category(7), datetime64[ns](2), float64(1), int64(3), object(8)
# memory usage: 50.2+ KB

# %%
import re

def extract_channel(notes):
    if pd.isna(notes):
        return 'unknown'
    
    found = re.search(r"Reached via\s+([^.;]+)", notes)
    if found:
        return found.group(1).strip().lower()
    
    return 'unknown'

# %%
combined_all['first_contact_channel'] = combined_all["notes"].apply(extract_channel)

# %%
combined_all.head()
# Out:
#   event_id       topic     city_x  venue_capacity scheduled_date_time  \
# 0     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 1     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 2     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 3     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 4     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
#
#   instructor_id  base_price discount_code  discount_pct currency  ...  \
# 0          I001        3000     STUDENT15            15      INR  ...
# 1          I001        3000     STUDENT15            15      INR  ...
# 2          I001        3000     STUDENT15            15      INR  ...
# 3          I001        3000     STUDENT15            15      INR  ...
# 4          I001        3000     STUDENT15            15      INR  ...
#
#       attendee_email       reg_timestamp payment_status ticket_type  \
# 0  user0@example.com 2025-12-31 10:00:00           paid   earlybird
# 1  user1@example.com 2025-12-18 10:00:00      cancelled    standard
# 2  user2@example.com 2025-12-23 10:00:00        pending     student
# 3  user3@example.com 2026-01-11 10:00:00           paid     student
# 4  user4@example.com 2025-12-14 10:00:00        pending    standard
#
#      company          role     city_y   industry  \
# 0    Contoso       Student       Pune         IT
# 1  Northwind      Engineer     Mysuru  Education
# 2   Fabrikam       Student       Pune    Finance
# 3   Fabrikam  Data Analyst       Pune    Finance
# 4    Contoso      Engineer  Hyderabad    Finance
#
#                                                notes first_contact_channel
# 0  Reached via partner. Promo=STUDENT15; Phone:+9...               partner
# 1  Reached via email. Promo=STUDENT15; Phone:+91-...                 email
# 2  Reached via partner. Promo=STUDENT15; Phone:+9...               partner
# 3  Reached via email. Promo=NA; Phone:+91-7059780...                 email
# 4  Reached via partner. Promo=NA; Phone:+91-97425...               partner
#
# [5 rows x 22 columns]

# %% [markdown]
# Lead time in number of days

# %%
combined_all['registration_lead_days'] = (combined_all['scheduled_date_time'] - combined_all['reg_timestamp']).dt.days

# %%
combined_all.head()
# Out:
#   event_id       topic     city_x  venue_capacity scheduled_date_time  \
# 0     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 1     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 2     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 3     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 4     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
#
#   instructor_id  base_price discount_code  discount_pct currency  ...  \
# 0          I001        3000     STUDENT15            15      INR  ...
# 1          I001        3000     STUDENT15            15      INR  ...
# 2          I001        3000     STUDENT15            15      INR  ...
# 3          I001        3000     STUDENT15            15      INR  ...
# 4          I001        3000     STUDENT15            15      INR  ...
#
#         reg_timestamp payment_status ticket_type    company          role  \
# 0 2025-12-31 10:00:00           paid   earlybird    Contoso       Student
# 1 2025-12-18 10:00:00      cancelled    standard  Northwind      Engineer
# 2 2025-12-23 10:00:00        pending     student   Fabrikam       Student
# 3 2026-01-11 10:00:00           paid     student   Fabrikam  Data Analyst
# 4 2025-12-14 10:00:00        pending    standard    Contoso      Engineer
#
#       city_y   industry                                              notes  \
# 0       Pune         IT  Reached via partner. Promo=STUDENT15; Phone:+9...
# 1     Mysuru  Education  Reached via email. Promo=STUDENT15; Phone:+91-...
# 2       Pune    Finance  Reached via partner. Promo=STUDENT15; Phone:+9...
# 3       Pune    Finance  Reached via email. Promo=NA; Phone:+91-7059780...
# 4  Hyderabad    Finance  Reached via partner. Promo=NA; Phone:+91-97425...
#
#   first_contact_channel registration_lead_days
# 0               partner                     13
# 1                 email                     26
# 2               partner                     21
# 3                 email                      2
# 4               partner                     30
#
# [5 rows x 23 columns]

# %% [markdown]
# Day of the week

# %%
combined_all['event_day_of_week'] = combined_all['scheduled_date_time'].dt.day_name()

# %%
combined_all.head()
# Out:
#   event_id       topic     city_x  venue_capacity scheduled_date_time  \
# 0     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 1     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 2     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 3     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
# 4     E001  Python OOP  Bengaluru              50 2026-01-13 10:00:00
#
#   instructor_id  base_price discount_code  discount_pct currency  ...  \
# 0          I001        3000     STUDENT15            15      INR  ...
# 1          I001        3000     STUDENT15            15      INR  ...
# 2          I001        3000     STUDENT15            15      INR  ...
# 3          I001        3000     STUDENT15            15      INR  ...
# 4          I001        3000     STUDENT15            15      INR  ...
#
#    payment_status ticket_type    company          role     city_y   industry  \
# 0            paid   earlybird    Contoso       Student       Pune         IT
# 1       cancelled    standard  Northwind      Engineer     Mysuru  Education
# 2         pending     student   Fabrikam       Student       Pune    Finance
# 3            paid     student   Fabrikam  Data Analyst       Pune    Finance
# 4         pending    standard    Contoso      Engineer  Hyderabad    Finance
#
#                                                notes first_contact_channel  \
# 0  Reached via partner. Promo=STUDENT15; Phone:+9...               partner
# 1  Reached via email. Promo=STUDENT15; Phone:+91-...                 email
# 2  Reached via partner. Promo=STUDENT15; Phone:+9...               partner
# 3  Reached via email. Promo=NA; Phone:+91-7059780...                 email
# 4  Reached via partner. Promo=NA; Phone:+91-97425...               partner
#
#   registration_lead_days event_day_of_week
# 0                     13           Tuesday
# 1                     26           Tuesday
# 2                     21           Tuesday
# 3                      2           Tuesday
# 4                     30           Tuesday
#
# [5 rows x 24 columns]

# %%
combined_all_final = pd.merge(combined_all,channels_df,on="event_id", how="inner")

# %% [markdown]
# Writing to db

# %%
from sqlalchemy import create_engine

DBDIR = "C:\\Users\\VishwasKSingh\\Workspace\\kantar-workspace-1\\my_project\\dbs"
engine = create_engine(f"sqlite:///{DBDIR}/events.db")

with engine.begin() as conn:
    combined_all_final.to_sql(
        "events",
        con=conn,
        if_exists="replace",
        index=False
        
    )
